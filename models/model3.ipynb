# %%
from tensorflow import keras
from tensorflow.keras import layers
from data.load_data import load_data
from data.predict import extract_results

# %%
(train_images, train_labels,test_images, test_labels) = load_data() #load the mnist dataset

# %%
train_images.shape
# Out:
# (60000, 784)

# %%
test_images.shape
# Out:
# (10000, 784)

# %%
model = keras.Sequential([
    layers.Dense(units=512, activation='relu'),
    layers.Dense(units=256, activation='relu'),
    layers.Dense(units=128, activation='relu'),
    layers.Dense(units=64, activation='relu'),
    layers.Dense(units=10, activation='softmax')
])

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(train_images,train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 8s 14ms/step - loss: 0.2698 - accuracy: 0.9182
# Epoch 2/5
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0974 - accuracy: 0.9706
# Epoch 3/5
# 469/469 [==============================] - 7s 15ms/step - loss: 0.0659 - accuracy: 0.9798
# Epoch 4/5
# 469/469 [==============================] - 6s 14ms/step - loss: 0.0494 - accuracy: 0.9847
# Epoch 5/5
# 469/469 [==============================] - 7s 14ms/step - loss: 0.0388 - accuracy: 0.9886

# %%
predictions = model.predict(test_images)
predictions = extract_results(predictions)
predictions[:12]
# Out:
# 313/313 [==============================] - 1s 4ms/step
# [7, 2, 1, 0, 4, 1, 4, 3, 5, 9, 0, 6]

# %%
from data.predict import plot_results
plot_results(predictions, test_images, test_labels)
