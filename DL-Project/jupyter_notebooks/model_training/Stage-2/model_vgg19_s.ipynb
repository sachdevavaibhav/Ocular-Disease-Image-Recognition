# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow import keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip '/content/drive/MyDrive/ResearchWork_2023/Single_disease/train_images.zip'
# !unzip '/content/drive/MyDrive/ResearchWork_2023/Single_disease/test_images.zip'
# !unzip '/content/drive/MyDrive/ResearchWork_2023/Single_disease/val_images.zip'

# %%
# Load the pre-trained Inception-ResNet-V2 model
base_model = tf.keras.applications.vgg19.VGG19(weights='imagenet', include_top=False, input_shape=(299,299,3))

# Freeze the pre-trained weights
base_model.trainable = False

# Pass the input layer through the pre-trained model
features = base_model.output

outputs = tf.keras.layers.Flatten()(features)
outputs = tf.keras.layers.Dense(units=8, activation='softmax')(outputs)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80134624/80134624 [==============================] - 1s 0us/step

# %%
# !pip install tensorflow_addons
# import tensorflow_addons as tfa
accuracy = tf.keras.metrics.Accuracy()
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
# f1_score = tfa.metrics.F1Score(num_classes=8)
categorical_accuracy = tf.keras.metrics.CategoricalAccuracy()

# %%
# Create the model
model = tf.keras.Model(inputs=base_model.input, outputs=outputs)
# Compile the model
# base_learning_rate = 0.0001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001),
               loss=tf.keras.losses.CategoricalCrossentropy(),
              metrics=[categorical_accuracy, precision , recall])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 299, 299, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 299, 299, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 149, 149, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 149, 149, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 149, 149, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 74, 74, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 74, 74, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 74, 74, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 74, 74, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 74, 74, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 37, 37, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 37, 37, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 37, 37, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 37, 37, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 37, 37, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 18, 18, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 18, 18, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 9, 9, 512)         0
#
#  flatten (Flatten)           (None, 41472)             0
#
#  dense (Dense)               (None, 8)                 331784
#
# =================================================================
# Total params: 20,356,168
# Trainable params: 331,784
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %%
# Load the image data and one-hot encoded multi-label data
# Load the data from the excel sheet into a pandas dataframe
# Load both left and right eye dataset
base_path = '/content/drive/MyDrive/ResearchWork_2023/Single_disease'
train_df = pd.read_excel(f'{base_path}/train_labels.xlsx')
test_df = pd.read_excel(f'{base_path}/test_labels.xlsx')
val_df = pd.read_excel(f'{base_path}/val_labels.xlsx')
# Out:
# /usr/local/lib/python3.9/dist-packages/openpyxl/worksheet/_reader.py:312: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
train_df
# Out:
#       Unnamed: 0.2  Unnamed: 0  Unnamed: 0.1          Fundus  \
# 0                0           0             0      0_left.jpg
# 1                1           1             1      1_left.jpg
# 2                3           3             3      3_left.jpg
# 3                4           4             4      4_left.jpg
# 4                5           5             5      5_left.jpg
# ...            ...         ...           ...             ...
# 6455          6953        3477          3494  4683_right.jpg
# 6456          6954        3478          3495  4686_right.jpg
# 6457          6955        3479          3496  4688_right.jpg
# 6458          6956        3480          3497  4689_right.jpg
# 6459          6957        3481          3498  4690_right.jpg
#
#                          Diagnostic_Keywords  N  D  G  C  A  H  M  O
# 0                                   cataract  0  0  0  1  0  0  0  0
# 1                              normal fundus  1  0  0  0  0  0  0  0
# 2                              normal fundus  1  0  0  0  0  0  0  0
# 3                macular epiretinal membrane  0  0  0  0  0  0  0  1
# 4     moderate non proliferative retinopathy  0  1  0  0  0  0  0  0
# ...                                      ... .. .. .. .. .. .. .. ..
# 6455       mild nonproliferative retinopathy  0  1  0  0  0  0  0  0
# 6456      proliferative diabetic retinopathy  0  1  0  0  0  0  0  0
# 6457  moderate non proliferative retinopathy  0  1  0  0  0  0  0  0
# 6458                           normal fundus  1  0  0  0  0  0  0  0
# 6459       mild nonproliferative retinopathy  0  1  0  0  0  0  0  0
#
# [6460 rows x 13 columns]

# %% [markdown]
# # Train

# %%
labels = train_df.iloc[:, 3:].values

# %%
# labels

# %%
# Split the data into two arrays, one for the image paths and one for the labels
train_images_base_path = '/content/train_cropped_images/'
image_paths = train_images_base_path + train_df["Fundus"].values
labels = train_df.iloc[:, 5:].values

# Convert the lists to tensors
image_paths = tf.constant(image_paths)
labels = tf.constant(labels)

# Create a dataset from the image paths and labels
train_dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))

# %% [markdown]
# # Test

# %%
# Split the data into two arrays, one for the image paths and one for the labels
test_images_base_path = '/content/test_cropped_images/'
image_paths = test_images_base_path + test_df["Fundus"].values
labels = test_df.iloc[:, 5:].values

# Convert the lists to tensors
image_paths = tf.constant(image_paths)
labels = tf.constant(labels)

# Create a dataset from the image paths and labels
test_dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))

# %% [markdown]
# # Validation

# %%
# Split the data into two arrays, one for the image paths and one for the labels
val_images_base_path = '/content/val_cropped_images/'
image_paths = val_images_base_path + val_df["Fundus"].values
labels = val_df.iloc[:, 5:].values

# Convert the lists to tensors
image_paths = tf.constant(image_paths)
labels = tf.constant(labels)

# Create a dataset from the image paths and labels
val_dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))

# %%
# Load the images and preprocess them
def load_and_preprocess_image(file_path, label):
    image = tf.io.read_file(file_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [299, 299])
    image = tf.keras.applications.vgg19.preprocess_input(image)
    return image, label

# Apply the load_and_preprocess_image function to the dataset
train_dataset = train_dataset.map(load_and_preprocess_image)
test_dataset = test_dataset.map(load_and_preprocess_image)
val_dataset = val_dataset.map(load_and_preprocess_image)

# Shuffle the data and batch it
batch_size = 32
train_dataset = train_dataset.shuffle(buffer_size=len(image_paths)).batch(batch_size)
test_dataset = test_dataset.shuffle(buffer_size=len(image_paths)).batch(batch_size)
val_dataset = val_dataset.shuffle(buffer_size=len(image_paths)).batch(batch_size)

# %%
train_dataset
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 8), dtype=tf.int64, name=None))>

# %%
test_dataset
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 8), dtype=tf.int64, name=None))>

# %%
val_dataset
# Out:
# <_BatchDataset element_spec=(TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 8), dtype=tf.int64, name=None))>

# %%
# Train the model
history=model.fit(train_dataset, epochs=20, batch_size=batch_size, validation_data=val_dataset)
# Out:
# Epoch 1/20
# 202/202 [==============================] - 144s 564ms/step - loss: 3.5467 - categorical_accuracy: 0.4760 - precision: 0.4815 - recall: 0.4670 - val_loss: 4.9656 - val_categorical_accuracy: 0.3418 - val_precision: 0.3405 - val_recall: 0.3344
# Epoch 2/20
# 202/202 [==============================] - 112s 501ms/step - loss: 1.9056 - categorical_accuracy: 0.6034 - precision: 0.6131 - recall: 0.5954 - val_loss: 5.0751 - val_categorical_accuracy: 0.3291 - val_precision: 0.3333 - val_recall: 0.3217
# Epoch 3/20
# 202/202 [==============================] - 114s 512ms/step - loss: 1.1311 - categorical_accuracy: 0.7067 - precision: 0.7181 - recall: 0.6960 - val_loss: 4.1216 - val_categorical_accuracy: 0.4299 - val_precision: 0.4344 - val_recall: 0.4214
# Epoch 4/20
# 202/202 [==============================] - 111s 507ms/step - loss: 0.6880 - categorical_accuracy: 0.7902 - precision: 0.7996 - recall: 0.7779 - val_loss: 4.2981 - val_categorical_accuracy: 0.4268 - val_precision: 0.4295 - val_recall: 0.4204
# Epoch 5/20
# 202/202 [==============================] - 110s 489ms/step - loss: 0.4422 - categorical_accuracy: 0.8485 - precision: 0.8570 - recall: 0.8407 - val_loss: 4.0562 - val_categorical_accuracy: 0.4013 - val_precision: 0.4061 - val_recall: 0.3949
# Epoch 6/20
# 202/202 [==============================] - 112s 510ms/step - loss: 0.3204 - categorical_accuracy: 0.8844 - precision: 0.8891 - recall: 0.8763 - val_loss: 4.1084 - val_categorical_accuracy: 0.4501 - val_precision: 0.4528 - val_recall: 0.4427
# Epoch 7/20
# 202/202 [==============================] - 115s 523ms/step - loss: 0.2424 - categorical_accuracy: 0.9107 - precision: 0.9165 - recall: 0.9051 - val_loss: 3.5205 - val_categorical_accuracy: 0.4490 - val_precision: 0.4503 - val_recall: 0.4374
# Epoch 8/20
# 202/202 [==============================] - 112s 503ms/step - loss: 0.1559 - categorical_accuracy: 0.9440 - precision: 0.9471 - recall: 0.9401 - val_loss: 3.4348 - val_categorical_accuracy: 0.4268 - val_precision: 0.4312 - val_recall: 0.4193
# Epoch 9/20
# 202/202 [==============================] - 114s 509ms/step - loss: 0.1099 - categorical_accuracy: 0.9638 - precision: 0.9669 - recall: 0.9618 - val_loss: 3.6876 - val_categorical_accuracy: 0.4777 - val_precision: 0.4831 - val_recall: 0.4713
# Epoch 10/20
# 202/202 [==============================] - 115s 515ms/step - loss: 0.0969 - categorical_accuracy: 0.9693 - precision: 0.9714 - recall: 0.9661 - val_loss: 3.8766 - val_categorical_accuracy: 0.4544 - val_precision: 0.4570 - val_recall: 0.4459
# Epoch 11/20
# 202/202 [==============================] - 114s 511ms/step - loss: 0.0735 - categorical_accuracy: 0.9783 - precision: 0.9807 - recall: 0.9768 - val_loss: 4.0791 - val_categorical_accuracy: 0.4459 - val_precision: 0.4500 - val_recall: 0.4395
# Epoch 12/20
# 202/202 [==============================] - 115s 509ms/step - loss: 0.0791 - categorical_accuracy: 0.9755 - precision: 0.9766 - recall: 0.9741 - val_loss: 3.9878 - val_categorical_accuracy: 0.4193 - val_precision: 0.4250 - val_recall: 0.4183
# Epoch 13/20
# 202/202 [==============================] - 113s 507ms/step - loss: 0.1055 - categorical_accuracy: 0.9601 - precision: 0.9622 - recall: 0.9584 - val_loss: 3.7635 - val_categorical_accuracy: 0.4894 - val_precision: 0.4951 - val_recall: 0.4862
# Epoch 14/20
# 202/202 [==============================] - 115s 512ms/step - loss: 0.0420 - categorical_accuracy: 0.9893 - precision: 0.9902 - recall: 0.9889 - val_loss: 4.2580 - val_categorical_accuracy: 0.4214 - val_precision: 0.4228 - val_recall: 0.4130
# Epoch 15/20
# 202/202 [==============================] - 115s 517ms/step - loss: 0.0388 - categorical_accuracy: 0.9906 - precision: 0.9907 - recall: 0.9895 - val_loss: 3.8885 - val_categorical_accuracy: 0.4342 - val_precision: 0.4365 - val_recall: 0.4268
# Epoch 16/20
# 202/202 [==============================] - 113s 508ms/step - loss: 0.0188 - categorical_accuracy: 0.9983 - precision: 0.9985 - recall: 0.9980 - val_loss: 3.8538 - val_categorical_accuracy: 0.4703 - val_precision: 0.4717 - val_recall: 0.4597
# Epoch 17/20
# 202/202 [==============================] - 114s 517ms/step - loss: 0.0166 - categorical_accuracy: 0.9985 - precision: 0.9986 - recall: 0.9980 - val_loss: 4.1808 - val_categorical_accuracy: 0.4427 - val_precision: 0.4455 - val_recall: 0.4384
# Epoch 18/20
# 202/202 [==============================] - 114s 516ms/step - loss: 0.0134 - categorical_accuracy: 0.9992 - precision: 0.9994 - recall: 0.9991 - val_loss: 3.9577 - val_categorical_accuracy: 0.4607 - val_precision: 0.4625 - val_recall: 0.4512
# Epoch 19/20
# 202/202 [==============================] - 114s 518ms/step - loss: 0.0110 - categorical_accuracy: 0.9994 - precision: 0.9995 - recall: 0.9994 - val_loss: 4.0793 - val_categorical_accuracy: 0.4490 - val_precision: 0.4545 - val_recall: 0.4459
# Epoch 20/20
# 202/202 [==============================] - 112s 497ms/step - loss: 0.0101 - categorical_accuracy: 0.9998 - precision: 0.9998 - recall: 0.9998 - val_loss: 3.6806 - val_categorical_accuracy: 0.4565 - val_precision: 0.4595 - val_recall: 0.4512

# %%
model.save('/content/drive/MyDrive/ResearchWork_2023/models/model_vgg19_s.h5')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['categorical_accuracy'])
plt.plot(history.history['val_categorical_accuracy'])
plt.title('model accuracy')
plt.ylabel('categorical_accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
result = model.evaluate(test_dataset)
result
# Out:
# 60/60 [==============================] - 35s 408ms/step - loss: 3.9276 - categorical_accuracy: 0.4483 - precision: 0.4526 - recall: 0.4409
# [3.927586793899536, 0.4482576549053192, 0.4525745213031769, 0.4408659040927887]

# %%
# load_model = tf.keras.saving.load_model('/content/drive/MyDrive/ResearchWork_2023/models/model_4.h5',compile=False)

# %%
import numpy as np

# Assuming you have a test dataset 'test_data' with image tensors and corresponding labels
predictions = []
true_labels = []

# Iterate over the test dataset and make predictions
for images, labels in test_dataset:
    preds = model.predict(images)
    predictions.extend(np.argmax(preds, axis=1))
    true_labels.extend(np.argmax(labels, axis=1))

# Compute the confusion matrix
cm = tf.math.confusion_matrix(true_labels, predictions)

# Convert the confusion matrix to a NumPy array and print it
print("Confusion Matrix:")
print(cm.numpy())
# Out:
# 1/1 [==============================] - 1s 713ms/step
# 1/1 [==============================] - 0s 189ms/step
# 1/1 [==============================] - 0s 171ms/step
# 1/1 [==============================] - 0s 149ms/step
# 1/1 [==============================] - 0s 144ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 77ms/step
# 1/1 [==============================] - 0s 127ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 80ms/step
# 1/1 [==============================] - 0s 101ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 94ms/step
# 1/1 [==============================] - 0s 120ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 117ms/step
# 1/1 [==============================] - 0s 81ms/step
# 1/1 [==============================] - 0s 75ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 109ms/step
# 1/1 [==============================] - 0s 107ms/step
# 1/1 [==============================] - 0s 138ms/step
# 1/1 [==============================] - 0s 182ms/step
# 1/1 [==============================] - 0s 166ms/step
# 1/1 [==============================] - 0s 145ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 205ms/step
# Confusion Matrix:
# [[576 166   8   3   7   2   0  57]
#  [ 87  68   2   0   2   3   0  16]
#  [ 43   5  12   0   0   0   0   5]
#  [ 12   2   1  62   0   0   0   4]
#  [ 34  10   1   1   6   0   3  15]
#  [ 14   9   0   0   0   1   0   3]
#  [  9   1   0   3   1   0  42   2]
#  [269 146   9  11  16   1  62  82]]
