# %%
from tensorflow import keras
from tensorflow.keras import layers
from data.load_data import load_data
from data.predict import extract_results

# %%
(train_images, train_labels,test_images, test_labels) = load_data() #load the mnist dataset

train_images.shape
# Out:
# (60000, 784)

# %%
test_images.shape
# Out:
# (10000, 784)

# %%
model = keras.Sequential([
    layers.Dense(units=512, activation='relu'),
    layers.Dense(units=256, activation='relu'),
    layers.Dense(units=10, activation='softmax')
])

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

model.fit(train_images,train_labels, epochs=30, batch_size=128)
# Out:
# Epoch 1/30
# 469/469 [==============================] - 5s 9ms/step - loss: 0.2268 - accuracy: 0.9305
# Epoch 2/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0829 - accuracy: 0.9748
# Epoch 3/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0553 - accuracy: 0.9829
# Epoch 4/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0392 - accuracy: 0.9879
# Epoch 5/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0302 - accuracy: 0.9906
# Epoch 6/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0228 - accuracy: 0.9928
# Epoch 7/30
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0176 - accuracy: 0.9944
# Epoch 8/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0157 - accuracy: 0.9947
# Epoch 9/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0123 - accuracy: 0.9960
# Epoch 10/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0098 - accuracy: 0.9969
# Epoch 11/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0082 - accuracy: 0.9974
# Epoch 12/30
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0072 - accuracy: 0.9977
# Epoch 13/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0072 - accuracy: 0.9978
# Epoch 14/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0061 - accuracy: 0.9982
# Epoch 15/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0060 - accuracy: 0.9983
# Epoch 16/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0054 - accuracy: 0.9981
# Epoch 17/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0048 - accuracy: 0.9984
# Epoch 18/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0043 - accuracy: 0.9987
# Epoch 19/30
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0049 - accuracy: 0.9985
# Epoch 20/30
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0046 - accuracy: 0.9986
# Epoch 21/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0033 - accuracy: 0.9990
# Epoch 22/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0044 - accuracy: 0.9987
# Epoch 23/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0035 - accuracy: 0.9990
# Epoch 24/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0043 - accuracy: 0.9989
# Epoch 25/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0037 - accuracy: 0.9991
# Epoch 26/30
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0033 - accuracy: 0.9991
# Epoch 27/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0028 - accuracy: 0.9992
# Epoch 28/30
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0030 - accuracy: 0.9994
# Epoch 29/30
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 30/30
# 469/469 [==============================] - 4s 10ms/step - loss: 0.0023 - accuracy: 0.9993

# %%
predictions = model.predict(test_images)
predictions = extract_results(predictions)
predictions[:12]
# Out:
# 313/313 [==============================] - 1s 2ms/step
# [7, 2, 1, 0, 4, 1, 4, 9, 5, 9, 0, 6]

# %%
from data.predict import plot_results
plot_results(predictions, test_images, test_labels)
