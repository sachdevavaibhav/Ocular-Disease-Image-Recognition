# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow import keras

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !unzip '/content/drive/MyDrive/ResearchWork_2023/cropped_images_zip/cropped_training_images.zip'
# Out:
# Archive:  /content/drive/MyDrive/ResearchWork_2023/cropped_images_zip/cropped_training_images.zip
# replace cropped_training_images/0_left.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename:
# error:  invalid response [{ENTER}]
# replace cropped_training_images/0_left.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: None

# %%
# Load the pre-trained Inception-ResNet-V2 model
base_model = tf.keras.applications.InceptionResNetV2(weights='imagenet', include_top=False, input_shape=(250,250,3))

# Freeze the pre-trained weights
base_model.trainable = False

# Define the input shape
input_shape = (250, 250, 3)

# Define the input layer
# inputs = tf.keras.layers.Input(shape=input_shape)

# Pass the input layer through the pre-trained model
features = base_model.output

# Add a dense layer for multi-class classification
# outputs = tf.keras.layers.Dense(units=8, activation='sigmoid')(features)

outputs = tf.keras.layers.Flatten()(features)
outputs = tf.keras.layers.Dense(units=8, activation='sigmoid')(outputs)

# %%
# !pip install tensorflow_addons
import tensorflow_addons as tfa
accuracy = tf.keras.metrics.Accuracy()
precision = tf.keras.metrics.Precision()
recall = tf.keras.metrics.Recall()
f1_score = tfa.metrics.F1Score(num_classes=8
                               )
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tensorflow_addons in /usr/local/lib/python3.8/dist-packages (0.19.0)
# Requirement already satisfied: typeguard>=2.7 in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (2.7.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.8/dist-packages (from tensorflow_addons) (23.0)

# %%
# Create the model
model = tf.keras.Model(inputs=base_model.input, outputs=outputs)
# Compile the model
base_learning_rate = 0.00001
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
               loss='binary_crossentropy',
              metrics=['accuracy', precision , recall, f1_score])

# %%
model.summary()

# %%
# Load the image data and one-hot encoded multi-label data
# Load the data from the excel sheet into a pandas dataframe
# Load both left and right eye dataset
# base_path = 'C:/Users/User/DeepLearning/DL-Project'
# left_df = pd.read_excel(f'{base_path}/updated_left_eye.xlsx')
# right_df = pd.read_excel(f'{base_path}/updated_right_eye.xlsx')

# #concating both dataframes
# df = pd.concat([left_df, right_df], axis=0)


# # Split the data into two arrays, one for the image paths and one for the labels
# images_base_path = 'E:/odir-dataset/ODIR-5K/ODIR-5K/cropped_training_images/'
# image_paths = images_base_path + df["Fundus"].values
# labels = df.iloc[:, 3:].values

# # Convert the lists to tensors
# image_paths = tf.constant(image_paths)
# labels = tf.constant(labels)

# # Create a dataset from the image paths and labels
# dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))

# %%
# Load the image data and one-hot encoded multi-label data
# Load the data from the excel sheet into a pandas dataframe
# Load both left and right eye dataset
base_path = '/content/drive/MyDrive/ResearchWork_2023'
left_df = pd.read_excel(f'{base_path}/updated_left_eye.xlsx')
right_df = pd.read_excel(f'{base_path}/updated_right_eye.xlsx')

#concating both dataframes
df = pd.concat([left_df, right_df], axis=0)


# Split the data into two arrays, one for the image paths and one for the labels
images_base_path = '/content/cropped_training_images/'
image_paths = images_base_path + df["Fundus"].values
labels = df.iloc[:, 3:].values

# Convert the lists to tensors
image_paths = tf.constant(image_paths)
labels = tf.constant(labels)

# Create a dataset from the image paths and labels
dataset = tf.data.Dataset.from_tensor_slices((image_paths, labels))

# %%
# Load the images and preprocess them
def load_and_preprocess_image(file_path, label):
    image = tf.io.read_file(file_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [250, 250])
    image = tf.keras.applications.inception_resnet_v2.preprocess_input(image)
    return image, label

# Apply the load_and_preprocess_image function to the dataset
dataset = dataset.map(load_and_preprocess_image)

# Shuffle the data and batch it
batch_size = 64
dataset = dataset.shuffle(buffer_size=len(image_paths)).batch(batch_size)

# %%
dataset
# Out:
# <BatchDataset element_spec=(TensorSpec(shape=(None, 250, 250, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 8), dtype=tf.int64, name=None))>

# %%
def split_data(dataset, train_split, test_split, val_split):
    # Calculate the size of each split
    dataset_size = dataset.reduce(tf.constant(0, dtype=tf.int64), lambda acc, _: acc + 1).numpy()
    train_size = int(dataset_size * train_split)
    val_size = int(dataset_size * val_split)
    test_size = int(dataset_size * test_split)

    # Shuffle the elements of the dataset randomly
    dataset = dataset.shuffle(buffer_size=dataset_size, seed=42)

    # Split the dataset into train, validation, and test sets
    train_dataset = dataset.take(train_size)
    remaining_dataset = dataset.skip(train_size)
    val_dataset = remaining_dataset.take(val_size)
    test_dataset = remaining_dataset.skip(val_size)
    return train_dataset, test_dataset, val_dataset

# %%
# Split the data into training and validation sets
train_dataset, test_dataset, val_dataset = split_data(dataset, train_split=0.7, test_split=0.15, val_split=0.15)

# %%
# Train the model
history=model.fit(train_dataset, epochs=50, batch_size=batch_size, validation_data=test_dataset)
# Out:
# Epoch 1/50
# 76/76 [==============================] - 123s 967ms/step - loss: 0.3878 - accuracy: 0.3554 - precision: 0.2998 - recall: 0.2072 - f1_score: 0.1237 - val_loss: 0.3262 - val_accuracy: 0.4072 - val_precision: 0.4530 - val_recall: 0.2101 - val_f1_score: 0.1824
# Epoch 2/50
# 76/76 [==============================] - 96s 876ms/step - loss: 0.3118 - accuracy: 0.4448 - precision: 0.4957 - recall: 0.2319 - f1_score: 0.2251 - val_loss: 0.3005 - val_accuracy: 0.4623 - val_precision: 0.4992 - val_recall: 0.2774 - val_f1_score: 0.2507
# Epoch 3/50
# 76/76 [==============================] - 95s 877ms/step - loss: 0.2946 - accuracy: 0.4842 - precision: 0.5534 - recall: 0.2704 - f1_score: 0.2909 - val_loss: 0.2951 - val_accuracy: 0.4769 - val_precision: 0.5629 - val_recall: 0.2204 - val_f1_score: 0.3212
# Epoch 4/50
# 76/76 [==============================] - 95s 879ms/step - loss: 0.2844 - accuracy: 0.5109 - precision: 0.5803 - recall: 0.2906 - f1_score: 0.3196 - val_loss: 0.2788 - val_accuracy: 0.5389 - val_precision: 0.5952 - val_recall: 0.3440 - val_f1_score: 0.3219
# Epoch 5/50
# 76/76 [==============================] - 94s 871ms/step - loss: 0.2791 - accuracy: 0.5192 - precision: 0.5955 - recall: 0.2993 - f1_score: 0.3352 - val_loss: 0.2706 - val_accuracy: 0.5276 - val_precision: 0.5951 - val_recall: 0.3302 - val_f1_score: 0.3397
# Epoch 6/50
# 76/76 [==============================] - 94s 873ms/step - loss: 0.2727 - accuracy: 0.5332 - precision: 0.6040 - recall: 0.3222 - f1_score: 0.3498 - val_loss: 0.2657 - val_accuracy: 0.5537 - val_precision: 0.6407 - val_recall: 0.3105 - val_f1_score: 0.3939
# Epoch 7/50
# 76/76 [==============================] - 94s 874ms/step - loss: 0.2664 - accuracy: 0.5465 - precision: 0.6120 - recall: 0.3321 - f1_score: 0.3629 - val_loss: 0.2565 - val_accuracy: 0.5537 - val_precision: 0.6483 - val_recall: 0.3141 - val_f1_score: 0.3891
# Epoch 8/50
# 76/76 [==============================] - 93s 871ms/step - loss: 0.2624 - accuracy: 0.5531 - precision: 0.6231 - recall: 0.3320 - f1_score: 0.3766 - val_loss: 0.2666 - val_accuracy: 0.5230 - val_precision: 0.6295 - val_recall: 0.2558 - val_f1_score: 0.3884
# Epoch 9/50
# 76/76 [==============================] - 96s 880ms/step - loss: 0.2598 - accuracy: 0.5549 - precision: 0.6377 - recall: 0.3402 - f1_score: 0.3935 - val_loss: 0.2535 - val_accuracy: 0.5846 - val_precision: 0.6738 - val_recall: 0.3482 - val_f1_score: 0.3951
# Epoch 10/50
# 76/76 [==============================] - 94s 875ms/step - loss: 0.2558 - accuracy: 0.5643 - precision: 0.6433 - recall: 0.3545 - f1_score: 0.3976 - val_loss: 0.2577 - val_accuracy: 0.5570 - val_precision: 0.6817 - val_recall: 0.3228 - val_f1_score: 0.3746
# Epoch 11/50
# 76/76 [==============================] - 94s 874ms/step - loss: 0.2521 - accuracy: 0.5717 - precision: 0.6598 - recall: 0.3575 - f1_score: 0.4064 - val_loss: 0.2476 - val_accuracy: 0.5754 - val_precision: 0.6499 - val_recall: 0.4192 - val_f1_score: 0.4087
# Epoch 12/50
# 76/76 [==============================] - 95s 878ms/step - loss: 0.2494 - accuracy: 0.5723 - precision: 0.6644 - recall: 0.3765 - f1_score: 0.4097 - val_loss: 0.2406 - val_accuracy: 0.5809 - val_precision: 0.7095 - val_recall: 0.3605 - val_f1_score: 0.4349
# Epoch 13/50
# 76/76 [==============================] - 95s 873ms/step - loss: 0.2476 - accuracy: 0.5787 - precision: 0.6578 - recall: 0.3713 - f1_score: 0.4291 - val_loss: 0.2425 - val_accuracy: 0.6185 - val_precision: 0.7277 - val_recall: 0.4085 - val_f1_score: 0.4277
# Epoch 14/50
# 76/76 [==============================] - 96s 888ms/step - loss: 0.2434 - accuracy: 0.5900 - precision: 0.6756 - recall: 0.3910 - f1_score: 0.4362 - val_loss: 0.2382 - val_accuracy: 0.6011 - val_precision: 0.6910 - val_recall: 0.3867 - val_f1_score: 0.4755
# Epoch 15/50
# 76/76 [==============================] - 95s 874ms/step - loss: 0.2395 - accuracy: 0.5970 - precision: 0.6868 - recall: 0.3944 - f1_score: 0.4481 - val_loss: 0.2377 - val_accuracy: 0.6075 - val_precision: 0.6985 - val_recall: 0.4088 - val_f1_score: 0.4452
# Epoch 16/50
# 76/76 [==============================] - 96s 887ms/step - loss: 0.2365 - accuracy: 0.6012 - precision: 0.6878 - recall: 0.4069 - f1_score: 0.4526 - val_loss: 0.2308 - val_accuracy: 0.6075 - val_precision: 0.7157 - val_recall: 0.3678 - val_f1_score: 0.4661
# Epoch 17/50
# 76/76 [==============================] - 95s 874ms/step - loss: 0.2370 - accuracy: 0.6001 - precision: 0.6999 - recall: 0.3973 - f1_score: 0.4639 - val_loss: 0.2367 - val_accuracy: 0.6011 - val_precision: 0.6601 - val_recall: 0.4573 - val_f1_score: 0.4725
# Epoch 18/50
# 76/76 [==============================] - 95s 875ms/step - loss: 0.2338 - accuracy: 0.6030 - precision: 0.6961 - recall: 0.4089 - f1_score: 0.4736 - val_loss: 0.2299 - val_accuracy: 0.6250 - val_precision: 0.7224 - val_recall: 0.3708 - val_f1_score: 0.4709
# Epoch 19/50
# 76/76 [==============================] - 95s 875ms/step - loss: 0.2303 - accuracy: 0.6104 - precision: 0.6999 - recall: 0.4109 - f1_score: 0.4854 - val_loss: 0.2219 - val_accuracy: 0.6222 - val_precision: 0.6943 - val_recall: 0.4573 - val_f1_score: 0.4614
# Epoch 20/50
# 76/76 [==============================] - 95s 874ms/step - loss: 0.2281 - accuracy: 0.6145 - precision: 0.7095 - recall: 0.4176 - f1_score: 0.4907 - val_loss: 0.2256 - val_accuracy: 0.6158 - val_precision: 0.7188 - val_recall: 0.4254 - val_f1_score: 0.5138
# Epoch 21/50
# 76/76 [==============================] - 93s 867ms/step - loss: 0.2267 - accuracy: 0.6180 - precision: 0.7114 - recall: 0.4223 - f1_score: 0.5015 - val_loss: 0.2214 - val_accuracy: 0.6333 - val_precision: 0.7351 - val_recall: 0.4305 - val_f1_score: 0.5316
# Epoch 22/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.2241 - accuracy: 0.6199 - precision: 0.7257 - recall: 0.4247 - f1_score: 0.5132 - val_loss: 0.2239 - val_accuracy: 0.6397 - val_precision: 0.7279 - val_recall: 0.4508 - val_f1_score: 0.5282
# Epoch 23/50
# 76/76 [==============================] - 93s 876ms/step - loss: 0.2234 - accuracy: 0.6238 - precision: 0.7159 - recall: 0.4363 - f1_score: 0.5123 - val_loss: 0.2245 - val_accuracy: 0.6186 - val_precision: 0.7424 - val_recall: 0.4092 - val_f1_score: 0.4952
# Epoch 24/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.2224 - accuracy: 0.6301 - precision: 0.7207 - recall: 0.4322 - f1_score: 0.5210 - val_loss: 0.2153 - val_accuracy: 0.6500 - val_precision: 0.7443 - val_recall: 0.4792 - val_f1_score: 0.5255
# Epoch 25/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.2187 - accuracy: 0.6377 - precision: 0.7291 - recall: 0.4458 - f1_score: 0.5238 - val_loss: 0.2186 - val_accuracy: 0.6204 - val_precision: 0.7420 - val_recall: 0.4252 - val_f1_score: 0.5018
# Epoch 26/50
# 76/76 [==============================] - 93s 867ms/step - loss: 0.2167 - accuracy: 0.6380 - precision: 0.7385 - recall: 0.4478 - f1_score: 0.5280 - val_loss: 0.2145 - val_accuracy: 0.6608 - val_precision: 0.7672 - val_recall: 0.4545 - val_f1_score: 0.5235
# Epoch 27/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.2151 - accuracy: 0.6431 - precision: 0.7384 - recall: 0.4555 - f1_score: 0.5418 - val_loss: 0.2069 - val_accuracy: 0.6645 - val_precision: 0.7433 - val_recall: 0.4793 - val_f1_score: 0.5525
# Epoch 28/50
# 76/76 [==============================] - 94s 873ms/step - loss: 0.2142 - accuracy: 0.6486 - precision: 0.7403 - recall: 0.4540 - f1_score: 0.5411 - val_loss: 0.2084 - val_accuracy: 0.6581 - val_precision: 0.7458 - val_recall: 0.4532 - val_f1_score: 0.5461
# Epoch 29/50
# 76/76 [==============================] - 93s 869ms/step - loss: 0.2117 - accuracy: 0.6515 - precision: 0.7502 - recall: 0.4567 - f1_score: 0.5535 - val_loss: 0.2123 - val_accuracy: 0.6379 - val_precision: 0.7375 - val_recall: 0.4795 - val_f1_score: 0.5614
# Epoch 30/50
# 76/76 [==============================] - 94s 879ms/step - loss: 0.2108 - accuracy: 0.6559 - precision: 0.7457 - recall: 0.4670 - f1_score: 0.5510 - val_loss: 0.1990 - val_accuracy: 0.6866 - val_precision: 0.8021 - val_recall: 0.4596 - val_f1_score: 0.5949
# Epoch 31/50
# 76/76 [==============================] - 93s 870ms/step - loss: 0.2093 - accuracy: 0.6571 - precision: 0.7548 - recall: 0.4704 - f1_score: 0.5591 - val_loss: 0.2042 - val_accuracy: 0.6581 - val_precision: 0.7697 - val_recall: 0.4708 - val_f1_score: 0.5750
# Epoch 32/50
# 76/76 [==============================] - 94s 874ms/step - loss: 0.2053 - accuracy: 0.6582 - precision: 0.7528 - recall: 0.4823 - f1_score: 0.5693 - val_loss: 0.2049 - val_accuracy: 0.6645 - val_precision: 0.7535 - val_recall: 0.4642 - val_f1_score: 0.5789
# Epoch 33/50
# 76/76 [==============================] - 94s 874ms/step - loss: 0.2071 - accuracy: 0.6547 - precision: 0.7554 - recall: 0.4773 - f1_score: 0.5769 - val_loss: 0.1984 - val_accuracy: 0.6893 - val_precision: 0.7715 - val_recall: 0.5273 - val_f1_score: 0.5555
# Epoch 34/50
# 76/76 [==============================] - 93s 870ms/step - loss: 0.2043 - accuracy: 0.6628 - precision: 0.7549 - recall: 0.4790 - f1_score: 0.5794 - val_loss: 0.2007 - val_accuracy: 0.6731 - val_precision: 0.7768 - val_recall: 0.4749 - val_f1_score: 0.5859
# Epoch 35/50
# 76/76 [==============================] - 93s 871ms/step - loss: 0.2032 - accuracy: 0.6669 - precision: 0.7646 - recall: 0.4865 - f1_score: 0.5877 - val_loss: 0.1999 - val_accuracy: 0.6756 - val_precision: 0.7558 - val_recall: 0.5000 - val_f1_score: 0.5628
# Epoch 36/50
# 76/76 [==============================] - 93s 872ms/step - loss: 0.2008 - accuracy: 0.6734 - precision: 0.7669 - recall: 0.4858 - f1_score: 0.5926 - val_loss: 0.1992 - val_accuracy: 0.6875 - val_precision: 0.7742 - val_recall: 0.5055 - val_f1_score: 0.5865
# Epoch 37/50
# 76/76 [==============================] - 93s 876ms/step - loss: 0.2000 - accuracy: 0.6717 - precision: 0.7750 - recall: 0.4939 - f1_score: 0.5964 - val_loss: 0.1977 - val_accuracy: 0.6884 - val_precision: 0.7478 - val_recall: 0.5017 - val_f1_score: 0.5818
# Epoch 38/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.1976 - accuracy: 0.6856 - precision: 0.7739 - recall: 0.5042 - f1_score: 0.6001 - val_loss: 0.2019 - val_accuracy: 0.6710 - val_precision: 0.7874 - val_recall: 0.4674 - val_f1_score: 0.6344
# Epoch 39/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.1967 - accuracy: 0.6763 - precision: 0.7755 - recall: 0.5106 - f1_score: 0.6058 - val_loss: 0.2003 - val_accuracy: 0.6728 - val_precision: 0.7832 - val_recall: 0.5103 - val_f1_score: 0.5916
# Epoch 40/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.1947 - accuracy: 0.6848 - precision: 0.7831 - recall: 0.5122 - f1_score: 0.6143 - val_loss: 0.1910 - val_accuracy: 0.7040 - val_precision: 0.7953 - val_recall: 0.5465 - val_f1_score: 0.6608
# Epoch 41/50
# 76/76 [==============================] - 93s 867ms/step - loss: 0.1955 - accuracy: 0.6812 - precision: 0.7733 - recall: 0.5046 - f1_score: 0.6080 - val_loss: 0.1904 - val_accuracy: 0.6829 - val_precision: 0.7620 - val_recall: 0.5300 - val_f1_score: 0.5976
# Epoch 42/50
# 76/76 [==============================] - 94s 878ms/step - loss: 0.1941 - accuracy: 0.6855 - precision: 0.7849 - recall: 0.5118 - f1_score: 0.6261 - val_loss: 0.1930 - val_accuracy: 0.7004 - val_precision: 0.7893 - val_recall: 0.5296 - val_f1_score: 0.6348
# Epoch 43/50
# 76/76 [==============================] - 93s 869ms/step - loss: 0.1915 - accuracy: 0.6891 - precision: 0.7759 - recall: 0.5143 - f1_score: 0.6253 - val_loss: 0.1960 - val_accuracy: 0.6991 - val_precision: 0.8155 - val_recall: 0.4785 - val_f1_score: 0.6842
# Epoch 44/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.1901 - accuracy: 0.6950 - precision: 0.7886 - recall: 0.5242 - f1_score: 0.6377 - val_loss: 0.1893 - val_accuracy: 0.6884 - val_precision: 0.7675 - val_recall: 0.5573 - val_f1_score: 0.6436
# Epoch 45/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.1878 - accuracy: 0.6993 - precision: 0.7867 - recall: 0.5289 - f1_score: 0.6397 - val_loss: 0.1859 - val_accuracy: 0.7065 - val_precision: 0.8196 - val_recall: 0.4940 - val_f1_score: 0.6547
# Epoch 46/50
# 76/76 [==============================] - 93s 870ms/step - loss: 0.1856 - accuracy: 0.6989 - precision: 0.7971 - recall: 0.5336 - f1_score: 0.6376 - val_loss: 0.1906 - val_accuracy: 0.6857 - val_precision: 0.7843 - val_recall: 0.5137 - val_f1_score: 0.6514
# Epoch 47/50
# 76/76 [==============================] - 93s 870ms/step - loss: 0.1858 - accuracy: 0.7050 - precision: 0.7990 - recall: 0.5434 - f1_score: 0.6497 - val_loss: 0.1844 - val_accuracy: 0.7105 - val_precision: 0.8003 - val_recall: 0.5358 - val_f1_score: 0.6498
# Epoch 48/50
# 76/76 [==============================] - 93s 872ms/step - loss: 0.1850 - accuracy: 0.7014 - precision: 0.7980 - recall: 0.5391 - f1_score: 0.6439 - val_loss: 0.1787 - val_accuracy: 0.7289 - val_precision: 0.8402 - val_recall: 0.5478 - val_f1_score: 0.6690
# Epoch 49/50
# 76/76 [==============================] - 94s 871ms/step - loss: 0.1857 - accuracy: 0.7033 - precision: 0.7997 - recall: 0.5297 - f1_score: 0.6346 - val_loss: 0.1779 - val_accuracy: 0.7050 - val_precision: 0.7931 - val_recall: 0.5725 - val_f1_score: 0.6172
# Epoch 50/50
# 76/76 [==============================] - 94s 874ms/step - loss: 0.1850 - accuracy: 0.7000 - precision: 0.8045 - recall: 0.5348 - f1_score: 0.6582 - val_loss: 0.1826 - val_accuracy: 0.7040 - val_precision: 0.8308 - val_recall: 0.5219 - val_f1_score: 0.6458

# %%
model.save('/content/drive/MyDrive/ResearchWork_2023/models/model_2_v3.h5')

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
new_model = tf.keras.models.load_model('/content/drive/MyDrive/ResearchWork_2023/models/model_2_v3.h5')

# %%
base_learning_rate = 0.00001
new_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
               loss='binary_crossentropy',
              metrics=['accuracy', precision , recall, f1_score])

# %%
new_history=new_model.fit(train_dataset, epochs=50, batch_size=batch_size, validation_data=test_dataset)
# Out:
# Epoch 1/50
# 76/76 [==============================] - 109s 917ms/step - loss: 0.1821 - accuracy: 0.7152 - precision: 0.8125 - recall: 0.5412 - f1_score: 0.6575 - val_loss: 0.1775 - val_accuracy: 0.7463 - val_precision: 0.8495 - val_recall: 0.5211 - val_f1_score: 0.7087
# Epoch 2/50
# 76/76 [==============================] - 94s 875ms/step - loss: 0.1796 - accuracy: 0.7183 - precision: 0.8071 - recall: 0.5492 - f1_score: 0.6606 - val_loss: 0.1781 - val_accuracy: 0.7325 - val_precision: 0.8519 - val_recall: 0.5341 - val_f1_score: 0.7005
# Epoch 3/50
# 76/76 [==============================] - 94s 873ms/step - loss: 0.1792 - accuracy: 0.7162 - precision: 0.8077 - recall: 0.5587 - f1_score: 0.6737 - val_loss: 0.1777 - val_accuracy: 0.7279 - val_precision: 0.8306 - val_recall: 0.5626 - val_f1_score: 0.6798
# Epoch 4/50
# 76/76 [==============================] - 93s 873ms/step - loss: 0.1754 - accuracy: 0.7311 - precision: 0.8195 - recall: 0.5665 - f1_score: 0.6819 - val_loss: 0.1764 - val_accuracy: 0.7261 - val_precision: 0.8108 - val_recall: 0.5622 - val_f1_score: 0.6899
# Epoch 5/50
# 76/76 [==============================] - 93s 871ms/step - loss: 0.1754 - accuracy: 0.7253 - precision: 0.8180 - recall: 0.5763 - f1_score: 0.6802 - val_loss: 0.1736 - val_accuracy: 0.7197 - val_precision: 0.8069 - val_recall: 0.6007 - val_f1_score: 0.6489
# Epoch 6/50
# 76/76 [==============================] - 94s 871ms/step - loss: 0.1743 - accuracy: 0.7300 - precision: 0.8209 - recall: 0.5656 - f1_score: 0.6783 - val_loss: 0.1722 - val_accuracy: 0.7509 - val_precision: 0.8451 - val_recall: 0.5740 - val_f1_score: 0.7064
# Epoch 7/50
# 76/76 [==============================] - 93s 872ms/step - loss: 0.1740 - accuracy: 0.7299 - precision: 0.8162 - recall: 0.5732 - f1_score: 0.6949 - val_loss: 0.1714 - val_accuracy: 0.7408 - val_precision: 0.8317 - val_recall: 0.6035 - val_f1_score: 0.7289
# Epoch 8/50
# 76/76 [==============================] - 94s 882ms/step - loss: 0.1727 - accuracy: 0.7303 - precision: 0.8243 - recall: 0.5740 - f1_score: 0.6871 - val_loss: 0.1724 - val_accuracy: 0.7279 - val_precision: 0.8249 - val_recall: 0.5747 - val_f1_score: 0.6895
# Epoch 9/50
# 76/76 [==============================] - 93s 873ms/step - loss: 0.1720 - accuracy: 0.7341 - precision: 0.8193 - recall: 0.5791 - f1_score: 0.6852 - val_loss: 0.1681 - val_accuracy: 0.7390 - val_precision: 0.8408 - val_recall: 0.5632 - val_f1_score: 0.7184
# Epoch 10/50
# 76/76 [==============================] - 93s 873ms/step - loss: 0.1705 - accuracy: 0.7350 - precision: 0.8258 - recall: 0.5755 - f1_score: 0.6929 - val_loss: 0.1723 - val_accuracy: 0.7316 - val_precision: 0.8146 - val_recall: 0.5851 - val_f1_score: 0.7189
# Epoch 11/50
# 76/76 [==============================] - 94s 877ms/step - loss: 0.1716 - accuracy: 0.7352 - precision: 0.8239 - recall: 0.5760 - f1_score: 0.6939 - val_loss: 0.1630 - val_accuracy: 0.7491 - val_precision: 0.8424 - val_recall: 0.5775 - val_f1_score: 0.7292
# Epoch 12/50
# 76/76 [==============================] - 94s 875ms/step - loss: 0.1686 - accuracy: 0.7420 - precision: 0.8328 - recall: 0.5908 - f1_score: 0.7042 - val_loss: 0.1633 - val_accuracy: 0.7509 - val_precision: 0.8263 - val_recall: 0.6117 - val_f1_score: 0.7322
# Epoch 13/50
# 76/76 [==============================] - 94s 874ms/step - loss: 0.1696 - accuracy: 0.7331 - precision: 0.8269 - recall: 0.5852 - f1_score: 0.7033 - val_loss: 0.1602 - val_accuracy: 0.7833 - val_precision: 0.8698 - val_recall: 0.6065 - val_f1_score: 0.7846
# Epoch 14/50
# 76/76 [==============================] - 93s 865ms/step - loss: 0.1665 - accuracy: 0.7465 - precision: 0.8340 - recall: 0.5934 - f1_score: 0.7187 - val_loss: 0.1670 - val_accuracy: 0.7463 - val_precision: 0.8409 - val_recall: 0.5842 - val_f1_score: 0.7657
# Epoch 15/50
# 76/76 [==============================] - 93s 873ms/step - loss: 0.1679 - accuracy: 0.7446 - precision: 0.8370 - recall: 0.5934 - f1_score: 0.7123 - val_loss: 0.1658 - val_accuracy: 0.7528 - val_precision: 0.8647 - val_recall: 0.5948 - val_f1_score: 0.7378
# Epoch 16/50
# 76/76 [==============================] - 94s 870ms/step - loss: 0.1650 - accuracy: 0.7580 - precision: 0.8334 - recall: 0.5966 - f1_score: 0.7269 - val_loss: 0.1668 - val_accuracy: 0.7279 - val_precision: 0.7823 - val_recall: 0.6430 - val_f1_score: 0.6749
# Epoch 17/50
# 76/76 [==============================] - 93s 870ms/step - loss: 0.1632 - accuracy: 0.7469 - precision: 0.8332 - recall: 0.5987 - f1_score: 0.7204 - val_loss: 0.1624 - val_accuracy: 0.7684 - val_precision: 0.8451 - val_recall: 0.5709 - val_f1_score: 0.7379
# Epoch 18/50
# 76/76 [==============================] - 94s 884ms/step - loss: 0.1619 - accuracy: 0.7551 - precision: 0.8365 - recall: 0.6108 - f1_score: 0.7262 - val_loss: 0.1587 - val_accuracy: 0.7629 - val_precision: 0.8384 - val_recall: 0.6028 - val_f1_score: 0.7255
# Epoch 19/50
# 76/76 [==============================] - 94s 876ms/step - loss: 0.1619 - accuracy: 0.7519 - precision: 0.8450 - recall: 0.6027 - f1_score: 0.7162 - val_loss: 0.1599 - val_accuracy: 0.7676 - val_precision: 0.8473 - val_recall: 0.6215 - val_f1_score: 0.7510
# Epoch 20/50
# 76/76 [==============================] - 94s 885ms/step - loss: 0.1625 - accuracy: 0.7535 - precision: 0.8390 - recall: 0.6128 - f1_score: 0.7347 - val_loss: 0.1503 - val_accuracy: 0.7868 - val_precision: 0.8614 - val_recall: 0.6551 - val_f1_score: 0.7428
# Epoch 21/50
# 76/76 [==============================] - 93s 873ms/step - loss: 0.1609 - accuracy: 0.7609 - precision: 0.8464 - recall: 0.6148 - f1_score: 0.7396 - val_loss: 0.1621 - val_accuracy: 0.7537 - val_precision: 0.8406 - val_recall: 0.6390 - val_f1_score: 0.7356
# Epoch 22/50
# 76/76 [==============================] - 93s 872ms/step - loss: 0.1605 - accuracy: 0.7584 - precision: 0.8474 - recall: 0.6158 - f1_score: 0.7377 - val_loss: 0.1541 - val_accuracy: 0.7822 - val_precision: 0.8814 - val_recall: 0.5907 - val_f1_score: 0.7624
# Epoch 23/50
# 76/76 [==============================] - 93s 872ms/step - loss: 0.1574 - accuracy: 0.7696 - precision: 0.8542 - recall: 0.6211 - f1_score: 0.7509 - val_loss: 0.1619 - val_accuracy: 0.7638 - val_precision: 0.8490 - val_recall: 0.6277 - val_f1_score: 0.7701
# Epoch 24/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.1587 - accuracy: 0.7657 - precision: 0.8482 - recall: 0.6159 - f1_score: 0.7506 - val_loss: 0.1598 - val_accuracy: 0.7500 - val_precision: 0.8496 - val_recall: 0.6179 - val_f1_score: 0.7707
# Epoch 25/50
# 76/76 [==============================] - 93s 867ms/step - loss: 0.1568 - accuracy: 0.7661 - precision: 0.8511 - recall: 0.6222 - f1_score: 0.7521 - val_loss: 0.1538 - val_accuracy: 0.7803 - val_precision: 0.8936 - val_recall: 0.6166 - val_f1_score: 0.7716
# Epoch 26/50
# 76/76 [==============================] - 93s 867ms/step - loss: 0.1556 - accuracy: 0.7704 - precision: 0.8563 - recall: 0.6353 - f1_score: 0.7425 - val_loss: 0.1531 - val_accuracy: 0.7803 - val_precision: 0.8632 - val_recall: 0.6278 - val_f1_score: 0.7561
# Epoch 27/50
# 76/76 [==============================] - 93s 870ms/step - loss: 0.1552 - accuracy: 0.7716 - precision: 0.8508 - recall: 0.6381 - f1_score: 0.7618 - val_loss: 0.1557 - val_accuracy: 0.7757 - val_precision: 0.8505 - val_recall: 0.6389 - val_f1_score: 0.7503
# Epoch 28/50
# 76/76 [==============================] - 94s 869ms/step - loss: 0.1535 - accuracy: 0.7706 - precision: 0.8554 - recall: 0.6341 - f1_score: 0.7601 - val_loss: 0.1554 - val_accuracy: 0.7794 - val_precision: 0.8517 - val_recall: 0.6475 - val_f1_score: 0.7598
# Epoch 29/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.1537 - accuracy: 0.7821 - precision: 0.8613 - recall: 0.6396 - f1_score: 0.7614 - val_loss: 0.1576 - val_accuracy: 0.7656 - val_precision: 0.8588 - val_recall: 0.6328 - val_f1_score: 0.7581
# Epoch 30/50
# 76/76 [==============================] - 94s 879ms/step - loss: 0.1536 - accuracy: 0.7772 - precision: 0.8586 - recall: 0.6329 - f1_score: 0.7734 - val_loss: 0.1557 - val_accuracy: 0.7748 - val_precision: 0.8921 - val_recall: 0.5820 - val_f1_score: 0.7585
# Epoch 31/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.1520 - accuracy: 0.7807 - precision: 0.8618 - recall: 0.6493 - f1_score: 0.7716 - val_loss: 0.1546 - val_accuracy: 0.7509 - val_precision: 0.8475 - val_recall: 0.6561 - val_f1_score: 0.7478
# Epoch 32/50
# 76/76 [==============================] - 93s 867ms/step - loss: 0.1517 - accuracy: 0.7797 - precision: 0.8608 - recall: 0.6484 - f1_score: 0.7590 - val_loss: 0.1496 - val_accuracy: 0.8079 - val_precision: 0.8943 - val_recall: 0.6704 - val_f1_score: 0.7737
# Epoch 33/50
# 76/76 [==============================] - 94s 867ms/step - loss: 0.1506 - accuracy: 0.7858 - precision: 0.8709 - recall: 0.6465 - f1_score: 0.7789 - val_loss: 0.1456 - val_accuracy: 0.7610 - val_precision: 0.8440 - val_recall: 0.6598 - val_f1_score: 0.7568
# Epoch 34/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.1498 - accuracy: 0.7839 - precision: 0.8632 - recall: 0.6535 - f1_score: 0.7731 - val_loss: 0.1466 - val_accuracy: 0.7978 - val_precision: 0.8806 - val_recall: 0.6500 - val_f1_score: 0.7948
# Epoch 35/50
# 76/76 [==============================] - 94s 876ms/step - loss: 0.1496 - accuracy: 0.7844 - precision: 0.8658 - recall: 0.6504 - f1_score: 0.7757 - val_loss: 0.1505 - val_accuracy: 0.7987 - val_precision: 0.8837 - val_recall: 0.6580 - val_f1_score: 0.7776
# Epoch 36/50
# 76/76 [==============================] - 93s 868ms/step - loss: 0.1491 - accuracy: 0.7846 - precision: 0.8639 - recall: 0.6507 - f1_score: 0.7752 - val_loss: 0.1487 - val_accuracy: 0.7840 - val_precision: 0.8808 - val_recall: 0.6338 - val_f1_score: 0.7819
# Epoch 37/50
# 76/76 [==============================] - 93s 873ms/step - loss: 0.1457 - accuracy: 0.8002 - precision: 0.8797 - recall: 0.6595 - f1_score: 0.7947 - val_loss: 0.1437 - val_accuracy: 0.8097 - val_precision: 0.8890 - val_recall: 0.6504 - val_f1_score: 0.7640
# Epoch 38/50
# 76/76 [==============================] - 94s 872ms/step - loss: 0.1451 - accuracy: 0.7988 - precision: 0.8705 - recall: 0.6690 - f1_score: 0.7926 - val_loss: 0.1454 - val_accuracy: 0.7981 - val_precision: 0.8743 - val_recall: 0.6766 - val_f1_score: 0.7928
# Epoch 39/50
# 76/76 [==============================] - 93s 871ms/step - loss: 0.1458 - accuracy: 0.7930 - precision: 0.8658 - recall: 0.6636 - f1_score: 0.7851 - val_loss: 0.1502 - val_accuracy: 0.7371 - val_precision: 0.8036 - val_recall: 0.6584 - val_f1_score: 0.7281
# Epoch 40/50
# 76/76 [==============================] - 93s 872ms/step - loss: 0.1446 - accuracy: 0.7937 - precision: 0.8698 - recall: 0.6657 - f1_score: 0.7944 - val_loss: 0.1441 - val_accuracy: 0.8102 - val_precision: 0.8773 - val_recall: 0.6898 - val_f1_score: 0.8330
# Epoch 41/50
# 76/76 [==============================] - 93s 873ms/step - loss: 0.1439 - accuracy: 0.8000 - precision: 0.8725 - recall: 0.6752 - f1_score: 0.7960 - val_loss: 0.1428 - val_accuracy: 0.7950 - val_precision: 0.8732 - val_recall: 0.6894 - val_f1_score: 0.7703
# Epoch 42/50
# 76/76 [==============================] - 93s 872ms/step - loss: 0.1435 - accuracy: 0.7985 - precision: 0.8766 - recall: 0.6711 - f1_score: 0.8036 - val_loss: 0.1419 - val_accuracy: 0.8171 - val_precision: 0.8989 - val_recall: 0.6838 - val_f1_score: 0.8365
# Epoch 43/50
# 76/76 [==============================] - 95s 870ms/step - loss: 0.1419 - accuracy: 0.8077 - precision: 0.8782 - recall: 0.6835 - f1_score: 0.8083 - val_loss: 0.1399 - val_accuracy: 0.8074 - val_precision: 0.8816 - val_recall: 0.6903 - val_f1_score: 0.8222
# Epoch 44/50
# 76/76 [==============================] - 94s 879ms/step - loss: 0.1424 - accuracy: 0.8023 - precision: 0.8736 - recall: 0.6796 - f1_score: 0.8044 - val_loss: 0.1337 - val_accuracy: 0.8226 - val_precision: 0.8979 - val_recall: 0.7074 - val_f1_score: 0.8215
# Epoch 45/50
# 76/76 [==============================] - 95s 877ms/step - loss: 0.1413 - accuracy: 0.8041 - precision: 0.8801 - recall: 0.6849 - f1_score: 0.7995 - val_loss: 0.1376 - val_accuracy: 0.8392 - val_precision: 0.9119 - val_recall: 0.6894 - val_f1_score: 0.8447
# Epoch 46/50
# 76/76 [==============================] - 94s 875ms/step - loss: 0.1401 - accuracy: 0.8145 - precision: 0.8857 - recall: 0.6853 - f1_score: 0.8192 - val_loss: 0.1424 - val_accuracy: 0.8033 - val_precision: 0.8768 - val_recall: 0.6710 - val_f1_score: 0.8134
# Epoch 47/50
# 76/76 [==============================] - 95s 886ms/step - loss: 0.1395 - accuracy: 0.8121 - precision: 0.8869 - recall: 0.6901 - f1_score: 0.8141 - val_loss: 0.1420 - val_accuracy: 0.8107 - val_precision: 0.9005 - val_recall: 0.6755 - val_f1_score: 0.8262
# Epoch 48/50
# 76/76 [==============================] - 93s 873ms/step - loss: 0.1393 - accuracy: 0.8049 - precision: 0.8838 - recall: 0.6920 - f1_score: 0.8134 - val_loss: 0.1378 - val_accuracy: 0.8454 - val_precision: 0.8964 - val_recall: 0.7154 - val_f1_score: 0.8478
# Epoch 49/50
# 76/76 [==============================] - 93s 871ms/step - loss: 0.1403 - accuracy: 0.8056 - precision: 0.8784 - recall: 0.6852 - f1_score: 0.8085 - val_loss: 0.1373 - val_accuracy: 0.8463 - val_precision: 0.9064 - val_recall: 0.7033 - val_f1_score: 0.8265
# Epoch 50/50
# 76/76 [==============================] - 94s 871ms/step - loss: 0.1391 - accuracy: 0.8116 - precision: 0.8766 - recall: 0.6880 - f1_score: 0.8136 - val_loss: 0.1370 - val_accuracy: 0.8281 - val_precision: 0.9051 - val_recall: 0.6833 - val_f1_score: 0.8462

# %%
model.save('/content/drive/MyDrive/ResearchWork_2023/models/model_2_v5.h5')

# %%
plt.plot(new_history.history['accuracy'])
plt.plot(new_history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()
# "Loss"
plt.plot(new_history.history['loss'])
plt.plot(new_history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
new_model_2 = tf.keras.models.load_model('/content/drive/MyDrive/ResearchWork_2023/models/model_2_v7.h5')

# %%
base_learning_rate = 0.00001
new_model_2.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
               loss='binary_crossentropy',
              metrics=['accuracy', precision , recall, f1_score])

# %%
base_model.output
# Out:
# <KerasTensor: shape=(None, 6, 6, 1536) dtype=float32 (created by layer 'conv_7b_ac')>

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 250, 250, 3  0           []
#                                 )]
#
#  conv2d_203 (Conv2D)            (None, 124, 124, 32  864         ['input_2[0][0]']
#                                 )
#
#  batch_normalization_203 (Batch  (None, 124, 124, 32  96         ['conv2d_203[0][0]']
#  Normalization)                 )
#
#  activation_203 (Activation)    (None, 124, 124, 32  0           ['batch_normalization_203[0][0]']
#                                 )
#
#  conv2d_204 (Conv2D)            (None, 122, 122, 32  9216        ['activation_203[0][0]']
#                                 )
#
#  batch_normalization_204 (Batch  (None, 122, 122, 32  96         ['conv2d_204[0][0]']
#  Normalization)                 )
#
#  activation_204 (Activation)    (None, 122, 122, 32  0           ['batch_normalization_204[0][0]']
#                                 )
#
#  conv2d_205 (Conv2D)            (None, 122, 122, 64  18432       ['activation_204[0][0]']
#                                 )
#
#  batch_normalization_205 (Batch  (None, 122, 122, 64  192        ['conv2d_205[0][0]']
#  Normalization)                 )
#
#  activation_205 (Activation)    (None, 122, 122, 64  0           ['batch_normalization_205[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 60, 60, 64)  0           ['activation_205[0][0]']
#
#  conv2d_206 (Conv2D)            (None, 60, 60, 80)   5120        ['max_pooling2d_4[0][0]']
#
#  batch_normalization_206 (Batch  (None, 60, 60, 80)  240         ['conv2d_206[0][0]']
#  Normalization)
#
#  activation_206 (Activation)    (None, 60, 60, 80)   0           ['batch_normalization_206[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 58, 58, 192)  138240      ['activation_206[0][0]']
#
#  batch_normalization_207 (Batch  (None, 58, 58, 192)  576        ['conv2d_207[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 58, 58, 192)  0           ['batch_normalization_207[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 28, 28, 192)  0          ['activation_207[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 28, 28, 64)   12288       ['max_pooling2d_5[0][0]']
#
#  batch_normalization_211 (Batch  (None, 28, 28, 64)  192         ['conv2d_211[0][0]']
#  Normalization)
#
#  activation_211 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_211[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 28, 28, 48)   9216        ['max_pooling2d_5[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 28, 28, 96)   55296       ['activation_211[0][0]']
#
#  batch_normalization_209 (Batch  (None, 28, 28, 48)  144         ['conv2d_209[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 28, 28, 96)  288         ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_209 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_212[0][0]']
#
#  average_pooling2d_1 (AveragePo  (None, 28, 28, 192)  0          ['max_pooling2d_5[0][0]']
#  oling2D)
#
#  conv2d_208 (Conv2D)            (None, 28, 28, 96)   18432       ['max_pooling2d_5[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 28, 28, 64)   76800       ['activation_209[0][0]']
#
#  conv2d_213 (Conv2D)            (None, 28, 28, 96)   82944       ['activation_212[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 28, 28, 64)   12288       ['average_pooling2d_1[0][0]']
#
#  batch_normalization_208 (Batch  (None, 28, 28, 96)  288         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_210 (Batch  (None, 28, 28, 64)  192         ['conv2d_210[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 28, 28, 96)  288         ['conv2d_213[0][0]']
#  Normalization)
#
#  batch_normalization_214 (Batch  (None, 28, 28, 64)  192         ['conv2d_214[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_208[0][0]']
#
#  activation_210 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_210[0][0]']
#
#  activation_213 (Activation)    (None, 28, 28, 96)   0           ['batch_normalization_213[0][0]']
#
#  activation_214 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_214[0][0]']
#
#  mixed_5b (Concatenate)         (None, 28, 28, 320)  0           ['activation_208[0][0]',
#                                                                   'activation_210[0][0]',
#                                                                   'activation_213[0][0]',
#                                                                   'activation_214[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 28, 28, 32)   10240       ['mixed_5b[0][0]']
#
#  batch_normalization_218 (Batch  (None, 28, 28, 32)  96          ['conv2d_218[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_218[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 28, 28, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_218[0][0]']
#
#  batch_normalization_216 (Batch  (None, 28, 28, 32)  96          ['conv2d_216[0][0]']
#  Normalization)
#
#  batch_normalization_219 (Batch  (None, 28, 28, 48)  144         ['conv2d_219[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_216[0][0]']
#
#  activation_219 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_219[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 28, 28, 32)   10240       ['mixed_5b[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_216[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_219[0][0]']
#
#  batch_normalization_215 (Batch  (None, 28, 28, 32)  96          ['conv2d_215[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 28, 28, 32)  96          ['conv2d_217[0][0]']
#  Normalization)
#
#  batch_normalization_220 (Batch  (None, 28, 28, 64)  192         ['conv2d_220[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_215[0][0]']
#
#  activation_217 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_217[0][0]']
#
#  activation_220 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_220[0][0]']
#
#  block35_1_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_215[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'activation_220[0][0]']
#
#  block35_1_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_1_mixed[0][0]']
#
#  block35_1 (Lambda)             (None, 28, 28, 320)  0           ['mixed_5b[0][0]',
#                                                                   'block35_1_conv[0][0]']
#
#  block35_1_ac (Activation)      (None, 28, 28, 320)  0           ['block35_1[0][0]']
#
#  conv2d_224 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_1_ac[0][0]']
#
#  batch_normalization_224 (Batch  (None, 28, 28, 32)  96          ['conv2d_224[0][0]']
#  Normalization)
#
#  activation_224 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_224[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_224[0][0]']
#
#  batch_normalization_222 (Batch  (None, 28, 28, 32)  96          ['conv2d_222[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 28, 28, 48)  144         ['conv2d_225[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_222[0][0]']
#
#  activation_225 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_225[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_1_ac[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_222[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_225[0][0]']
#
#  batch_normalization_221 (Batch  (None, 28, 28, 32)  96          ['conv2d_221[0][0]']
#  Normalization)
#
#  batch_normalization_223 (Batch  (None, 28, 28, 32)  96          ['conv2d_223[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 28, 28, 64)  192         ['conv2d_226[0][0]']
#  Normalization)
#
#  activation_221 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_221[0][0]']
#
#  activation_223 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_223[0][0]']
#
#  activation_226 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_226[0][0]']
#
#  block35_2_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_221[0][0]',
#                                                                   'activation_223[0][0]',
#                                                                   'activation_226[0][0]']
#
#  block35_2_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_2_mixed[0][0]']
#
#  block35_2 (Lambda)             (None, 28, 28, 320)  0           ['block35_1_ac[0][0]',
#                                                                   'block35_2_conv[0][0]']
#
#  block35_2_ac (Activation)      (None, 28, 28, 320)  0           ['block35_2[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_2_ac[0][0]']
#
#  batch_normalization_230 (Batch  (None, 28, 28, 32)  96          ['conv2d_230[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_230[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_230[0][0]']
#
#  batch_normalization_228 (Batch  (None, 28, 28, 32)  96          ['conv2d_228[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 28, 28, 48)  144         ['conv2d_231[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_231[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_2_ac[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_228[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_231[0][0]']
#
#  batch_normalization_227 (Batch  (None, 28, 28, 32)  96          ['conv2d_227[0][0]']
#  Normalization)
#
#  batch_normalization_229 (Batch  (None, 28, 28, 32)  96          ['conv2d_229[0][0]']
#  Normalization)
#
#  batch_normalization_232 (Batch  (None, 28, 28, 64)  192         ['conv2d_232[0][0]']
#  Normalization)
#
#  activation_227 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_227[0][0]']
#
#  activation_229 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_229[0][0]']
#
#  activation_232 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_232[0][0]']
#
#  block35_3_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_227[0][0]',
#                                                                   'activation_229[0][0]',
#                                                                   'activation_232[0][0]']
#
#  block35_3_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_3_mixed[0][0]']
#
#  block35_3 (Lambda)             (None, 28, 28, 320)  0           ['block35_2_ac[0][0]',
#                                                                   'block35_3_conv[0][0]']
#
#  block35_3_ac (Activation)      (None, 28, 28, 320)  0           ['block35_3[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_3_ac[0][0]']
#
#  batch_normalization_236 (Batch  (None, 28, 28, 32)  96          ['conv2d_236[0][0]']
#  Normalization)
#
#  activation_236 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_236[0][0]']
#
#  conv2d_234 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_236[0][0]']
#
#  batch_normalization_234 (Batch  (None, 28, 28, 32)  96          ['conv2d_234[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 28, 28, 48)  144         ['conv2d_237[0][0]']
#  Normalization)
#
#  activation_234 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_234[0][0]']
#
#  activation_237 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_237[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_3_ac[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_234[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_237[0][0]']
#
#  batch_normalization_233 (Batch  (None, 28, 28, 32)  96          ['conv2d_233[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 28, 28, 32)  96          ['conv2d_235[0][0]']
#  Normalization)
#
#  batch_normalization_238 (Batch  (None, 28, 28, 64)  192         ['conv2d_238[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_233[0][0]']
#
#  activation_235 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_235[0][0]']
#
#  activation_238 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_238[0][0]']
#
#  block35_4_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_233[0][0]',
#                                                                   'activation_235[0][0]',
#                                                                   'activation_238[0][0]']
#
#  block35_4_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_4_mixed[0][0]']
#
#  block35_4 (Lambda)             (None, 28, 28, 320)  0           ['block35_3_ac[0][0]',
#                                                                   'block35_4_conv[0][0]']
#
#  block35_4_ac (Activation)      (None, 28, 28, 320)  0           ['block35_4[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_4_ac[0][0]']
#
#  batch_normalization_242 (Batch  (None, 28, 28, 32)  96          ['conv2d_242[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_242[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_242[0][0]']
#
#  batch_normalization_240 (Batch  (None, 28, 28, 32)  96          ['conv2d_240[0][0]']
#  Normalization)
#
#  batch_normalization_243 (Batch  (None, 28, 28, 48)  144         ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_240[0][0]']
#
#  activation_243 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_243[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_4_ac[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_240[0][0]']
#
#  conv2d_244 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 28, 28, 32)  96          ['conv2d_239[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 28, 28, 32)  96          ['conv2d_241[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 28, 28, 64)  192         ['conv2d_244[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_239[0][0]']
#
#  activation_241 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_241[0][0]']
#
#  activation_244 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_244[0][0]']
#
#  block35_5_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_239[0][0]',
#                                                                   'activation_241[0][0]',
#                                                                   'activation_244[0][0]']
#
#  block35_5_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_5_mixed[0][0]']
#
#  block35_5 (Lambda)             (None, 28, 28, 320)  0           ['block35_4_ac[0][0]',
#                                                                   'block35_5_conv[0][0]']
#
#  block35_5_ac (Activation)      (None, 28, 28, 320)  0           ['block35_5[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_5_ac[0][0]']
#
#  batch_normalization_248 (Batch  (None, 28, 28, 32)  96          ['conv2d_248[0][0]']
#  Normalization)
#
#  activation_248 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_248[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_248[0][0]']
#
#  batch_normalization_246 (Batch  (None, 28, 28, 32)  96          ['conv2d_246[0][0]']
#  Normalization)
#
#  batch_normalization_249 (Batch  (None, 28, 28, 48)  144         ['conv2d_249[0][0]']
#  Normalization)
#
#  activation_246 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_246[0][0]']
#
#  activation_249 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_249[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_5_ac[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_246[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_249[0][0]']
#
#  batch_normalization_245 (Batch  (None, 28, 28, 32)  96          ['conv2d_245[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 28, 28, 32)  96          ['conv2d_247[0][0]']
#  Normalization)
#
#  batch_normalization_250 (Batch  (None, 28, 28, 64)  192         ['conv2d_250[0][0]']
#  Normalization)
#
#  activation_245 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_245[0][0]']
#
#  activation_247 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_247[0][0]']
#
#  activation_250 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_250[0][0]']
#
#  block35_6_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_245[0][0]',
#                                                                   'activation_247[0][0]',
#                                                                   'activation_250[0][0]']
#
#  block35_6_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_6_mixed[0][0]']
#
#  block35_6 (Lambda)             (None, 28, 28, 320)  0           ['block35_5_ac[0][0]',
#                                                                   'block35_6_conv[0][0]']
#
#  block35_6_ac (Activation)      (None, 28, 28, 320)  0           ['block35_6[0][0]']
#
#  conv2d_254 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_6_ac[0][0]']
#
#  batch_normalization_254 (Batch  (None, 28, 28, 32)  96          ['conv2d_254[0][0]']
#  Normalization)
#
#  activation_254 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_254[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_255 (Conv2D)            (None, 28, 28, 48)   13824       ['activation_254[0][0]']
#
#  batch_normalization_252 (Batch  (None, 28, 28, 32)  96          ['conv2d_252[0][0]']
#  Normalization)
#
#  batch_normalization_255 (Batch  (None, 28, 28, 48)  144         ['conv2d_255[0][0]']
#  Normalization)
#
#  activation_252 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_252[0][0]']
#
#  activation_255 (Activation)    (None, 28, 28, 48)   0           ['batch_normalization_255[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_6_ac[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 28, 28, 32)   9216        ['activation_252[0][0]']
#
#  conv2d_256 (Conv2D)            (None, 28, 28, 64)   27648       ['activation_255[0][0]']
#
#  batch_normalization_251 (Batch  (None, 28, 28, 32)  96          ['conv2d_251[0][0]']
#  Normalization)
#
#  batch_normalization_253 (Batch  (None, 28, 28, 32)  96          ['conv2d_253[0][0]']
#  Normalization)
#
#  batch_normalization_256 (Batch  (None, 28, 28, 64)  192         ['conv2d_256[0][0]']
#  Normalization)
#
#  activation_251 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_251[0][0]']
#
#  activation_253 (Activation)    (None, 28, 28, 32)   0           ['batch_normalization_253[0][0]']
#
#  activation_256 (Activation)    (None, 28, 28, 64)   0           ['batch_normalization_256[0][0]']
#
#  block35_7_mixed (Concatenate)  (None, 28, 28, 128)  0           ['activation_251[0][0]',
#                                                                   'activation_253[0][0]',
#                                                                   'activation_256[0][0]']
#
#  block35_7_conv (Conv2D)        (None, 28, 28, 320)  41280       ['block35_7_mixed[0][0]']
#
#  block35_7 (Lambda)             (None, 28, 28, 320)  0           ['block35_6_ac[0][0]',
#                                                                   'block35_7_conv[0][0]']
#
#  block35_7_ac (Activation)      (None, 28, 28, 320)  0           ['block35_7[0][0]']
#
#  conv2d_260 (Conv2D)            (None, 28, 28, 32)   10240       ['block35_7_ac[0][0]']
#
#  batch_normalization_260 (Batch  (None, 28, 28, 32)  96          ['conv2d_260[0][0]']
#  Normalization)
#
# ...
#  Normalization)
#
#  activation_391 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_391[0][0]']
#
#  conv2d_392 (Conv2D)            (None, 6, 6, 224)    129024      ['activation_391[0][0]']
#
#  batch_normalization_392 (Batch  (None, 6, 6, 224)   672         ['conv2d_392[0][0]']
#  Normalization)
#
#  activation_392 (Activation)    (None, 6, 6, 224)    0           ['batch_normalization_392[0][0]']
#
#  conv2d_390 (Conv2D)            (None, 6, 6, 192)    399360      ['block8_6_ac[0][0]']
#
#  conv2d_393 (Conv2D)            (None, 6, 6, 256)    172032      ['activation_392[0][0]']
#
#  batch_normalization_390 (Batch  (None, 6, 6, 192)   576         ['conv2d_390[0][0]']
#  Normalization)
#
#  batch_normalization_393 (Batch  (None, 6, 6, 256)   768         ['conv2d_393[0][0]']
#  Normalization)
#
#  activation_390 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_390[0][0]']
#
#  activation_393 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_393[0][0]']
#
#  block8_7_mixed (Concatenate)   (None, 6, 6, 448)    0           ['activation_390[0][0]',
#                                                                   'activation_393[0][0]']
#
#  block8_7_conv (Conv2D)         (None, 6, 6, 2080)   933920      ['block8_7_mixed[0][0]']
#
#  block8_7 (Lambda)              (None, 6, 6, 2080)   0           ['block8_6_ac[0][0]',
#                                                                   'block8_7_conv[0][0]']
#
#  block8_7_ac (Activation)       (None, 6, 6, 2080)   0           ['block8_7[0][0]']
#
#  conv2d_395 (Conv2D)            (None, 6, 6, 192)    399360      ['block8_7_ac[0][0]']
#
#  batch_normalization_395 (Batch  (None, 6, 6, 192)   576         ['conv2d_395[0][0]']
#  Normalization)
#
#  activation_395 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_395[0][0]']
#
#  conv2d_396 (Conv2D)            (None, 6, 6, 224)    129024      ['activation_395[0][0]']
#
#  batch_normalization_396 (Batch  (None, 6, 6, 224)   672         ['conv2d_396[0][0]']
#  Normalization)
#
#  activation_396 (Activation)    (None, 6, 6, 224)    0           ['batch_normalization_396[0][0]']
#
#  conv2d_394 (Conv2D)            (None, 6, 6, 192)    399360      ['block8_7_ac[0][0]']
#
#  conv2d_397 (Conv2D)            (None, 6, 6, 256)    172032      ['activation_396[0][0]']
#
#  batch_normalization_394 (Batch  (None, 6, 6, 192)   576         ['conv2d_394[0][0]']
#  Normalization)
#
#  batch_normalization_397 (Batch  (None, 6, 6, 256)   768         ['conv2d_397[0][0]']
#  Normalization)
#
#  activation_394 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_394[0][0]']
#
#  activation_397 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_397[0][0]']
#
#  block8_8_mixed (Concatenate)   (None, 6, 6, 448)    0           ['activation_394[0][0]',
#                                                                   'activation_397[0][0]']
#
#  block8_8_conv (Conv2D)         (None, 6, 6, 2080)   933920      ['block8_8_mixed[0][0]']
#
#  block8_8 (Lambda)              (None, 6, 6, 2080)   0           ['block8_7_ac[0][0]',
#                                                                   'block8_8_conv[0][0]']
#
#  block8_8_ac (Activation)       (None, 6, 6, 2080)   0           ['block8_8[0][0]']
#
#  conv2d_399 (Conv2D)            (None, 6, 6, 192)    399360      ['block8_8_ac[0][0]']
#
#  batch_normalization_399 (Batch  (None, 6, 6, 192)   576         ['conv2d_399[0][0]']
#  Normalization)
#
#  activation_399 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_399[0][0]']
#
#  conv2d_400 (Conv2D)            (None, 6, 6, 224)    129024      ['activation_399[0][0]']
#
#  batch_normalization_400 (Batch  (None, 6, 6, 224)   672         ['conv2d_400[0][0]']
#  Normalization)
#
#  activation_400 (Activation)    (None, 6, 6, 224)    0           ['batch_normalization_400[0][0]']
#
#  conv2d_398 (Conv2D)            (None, 6, 6, 192)    399360      ['block8_8_ac[0][0]']
#
#  conv2d_401 (Conv2D)            (None, 6, 6, 256)    172032      ['activation_400[0][0]']
#
#  batch_normalization_398 (Batch  (None, 6, 6, 192)   576         ['conv2d_398[0][0]']
#  Normalization)
#
#  batch_normalization_401 (Batch  (None, 6, 6, 256)   768         ['conv2d_401[0][0]']
#  Normalization)
#
#  activation_398 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_398[0][0]']
#
#  activation_401 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_401[0][0]']
#
#  block8_9_mixed (Concatenate)   (None, 6, 6, 448)    0           ['activation_398[0][0]',
#                                                                   'activation_401[0][0]']
#
#  block8_9_conv (Conv2D)         (None, 6, 6, 2080)   933920      ['block8_9_mixed[0][0]']
#
#  block8_9 (Lambda)              (None, 6, 6, 2080)   0           ['block8_8_ac[0][0]',
#                                                                   'block8_9_conv[0][0]']
#
#  block8_9_ac (Activation)       (None, 6, 6, 2080)   0           ['block8_9[0][0]']
#
#  conv2d_403 (Conv2D)            (None, 6, 6, 192)    399360      ['block8_9_ac[0][0]']
#
#  batch_normalization_403 (Batch  (None, 6, 6, 192)   576         ['conv2d_403[0][0]']
#  Normalization)
#
#  activation_403 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_403[0][0]']
#
#  conv2d_404 (Conv2D)            (None, 6, 6, 224)    129024      ['activation_403[0][0]']
#
#  batch_normalization_404 (Batch  (None, 6, 6, 224)   672         ['conv2d_404[0][0]']
#  Normalization)
#
#  activation_404 (Activation)    (None, 6, 6, 224)    0           ['batch_normalization_404[0][0]']
#
#  conv2d_402 (Conv2D)            (None, 6, 6, 192)    399360      ['block8_9_ac[0][0]']
#
#  conv2d_405 (Conv2D)            (None, 6, 6, 256)    172032      ['activation_404[0][0]']
#
#  batch_normalization_402 (Batch  (None, 6, 6, 192)   576         ['conv2d_402[0][0]']
#  Normalization)
#
#  batch_normalization_405 (Batch  (None, 6, 6, 256)   768         ['conv2d_405[0][0]']
#  Normalization)
#
#  activation_402 (Activation)    (None, 6, 6, 192)    0           ['batch_normalization_402[0][0]']
#
#  activation_405 (Activation)    (None, 6, 6, 256)    0           ['batch_normalization_405[0][0]']
#
#  block8_10_mixed (Concatenate)  (None, 6, 6, 448)    0           ['activation_402[0][0]',
#                                                                   'activation_405[0][0]']
#
#  block8_10_conv (Conv2D)        (None, 6, 6, 2080)   933920      ['block8_10_mixed[0][0]']
#
#  block8_10 (Lambda)             (None, 6, 6, 2080)   0           ['block8_9_ac[0][0]',
#                                                                   'block8_10_conv[0][0]']
#
#  conv_7b (Conv2D)               (None, 6, 6, 1536)   3194880     ['block8_10[0][0]']
#
#  conv_7b_bn (BatchNormalization  (None, 6, 6, 1536)  4608        ['conv_7b[0][0]']
#  )
#
#  conv_7b_ac (Activation)        (None, 6, 6, 1536)   0           ['conv_7b_bn[0][0]']
#
#  flatten_1 (Flatten)            (None, 55296)        0           ['conv_7b_ac[0][0]']
#
#  dense_1 (Dense)                (None, 8)            442376      ['flatten_1[0][0]']
#
# ==================================================================================================
# Total params: 54,779,112
# Trainable params: 442,376
# Non-trainable params: 54,336,736
# __________________________________________________________________________________________________
